# %%
import requests
import pandas as pd
import json
from dotenv import load_dotenv
import os
import time

load_dotenv()
KEY=os.getenv("APIKEY")

# %%
from pprint import pprint

# %%
# Covid article search
url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date=20200101&end_date=20230101&fq=headline%3A(%22covid%22%20%22coronavirus%22)&page=0&sort=oldest&api-key={KEY}"
requestHeaders = {"Accept": "application/json"}

response = requests.get(url, headers=requestHeaders).json()

print(len(response['response']['docs']))

pprint(response['response']['docs'][0])
# Out:
# 10
# {'_id': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#  'abstract': 'The two new patients will add to fears that the virus will '
#              'spread further outside China’s borders.',
#  'byline': {'organization': None,
#             'original': 'By Sui-Lee Wee',
#             'person': [{'firstname': 'Sui-lee',
#                         'lastname': 'Wee',
#                         'middlename': None,
#                         'organization': '',
#                         'qualifier': None,
#                         'rank': 1,
#                         'role': 'reported',
#                         'title': None}]},
#  'document_type': 'article',
#  'headline': {'content_kicker': None,
#               'kicker': None,
#               'main': 'Japan and Thailand Confirm New Cases of Chinese '
#                       'Coronavirus',
#               'name': None,
#               'print_headline': 'Japan Confirms Case of New Coronavirus; '
#                                 'Patient Had Visited China',
#               'seo': None,
#               'sub': None},
#  'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Viruses'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 2,
#                'value': 'Epidemics'},
#               {'major': 'N', 'name': 'glocations', 'rank': 3, 'value': 'China'},
#               {'major': 'N', 'name': 'glocations', 'rank': 4, 'value': 'Japan'},
#               {'major': 'N',
#                'name': 'glocations',
#                'rank': 5,
#                'value': 'Thailand'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 6,
#                'value': 'Coronavirus (2019-nCoV)'},
#               {'major': 'N',
#                'name': 'subject',
#                'rank': 7,
#                'value': 'Pneumonia'}],
#  'lead_paragraph': 'BEIJING — Thailand and Japan each reported new cases of a '
#                    'coronavirus that has left two people dead and at least 40 '
#                    'sick in China, adding to concerns about the spread of the '
#                    'virus beyond Chinese borders ahead of a major holiday. ',
#  'multimedia': [{'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleLarge',
#                  'height': 400,
#                  'legacy': {'xlarge': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-articleLarge.jpg',
#                             'xlargeheight': 400,
#                             'xlargewidth': 600},
#                  'rank': 0,
#                  'subType': 'xlarge',
#                  'subtype': 'xlarge',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-articleLarge.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'popup',
#                  'height': 433,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'popup',
#                  'subtype': 'popup',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-popup.jpg',
#                  'width': 650},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog480',
#                  'height': 320,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog480',
#                  'subtype': 'blog480',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-blog480.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog533',
#                  'height': 355,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog533',
#                  'subtype': 'blog533',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-blog533.jpg',
#                  'width': 533},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog427',
#                  'height': 285,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog427',
#                  'subtype': 'blog427',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-blog427.jpg',
#                  'width': 427},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagSF',
#                  'height': 241,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagSF',
#                  'subtype': 'tmagSF',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-tmagSF.jpg',
#                  'width': 362},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'tmagArticle',
#                  'height': 395,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'tmagArticle',
#                  'subtype': 'tmagArticle',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-tmagArticle.jpg',
#                  'width': 592},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'slide',
#                  'height': 400,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'slide',
#                  'subtype': 'slide',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-slide.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'jumbo',
#                  'height': 683,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'jumbo',
#                  'subtype': 'jumbo',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-jumbo.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'superJumbo',
#                  'height': 1366,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'superJumbo',
#                  'subtype': 'superJumbo',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-superJumbo.jpg',
#                  'width': 2048},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blog225',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blog225',
#                  'subtype': 'blog225',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-blog225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master1050',
#                  'height': 700,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master1050',
#                  'subtype': 'master1050',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master675',
#                  'height': 450,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master675',
#                  'subtype': 'master675',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master675.jpg',
#                  'width': 675},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master495',
#                  'height': 330,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master495',
#                  'subtype': 'master495',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master495.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master180',
#                  'height': 120,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master180',
#                  'subtype': 'master180',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master180.jpg',
#                  'width': 180},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master315',
#                  'height': 210,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master315',
#                  'subtype': 'master315',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master315.jpg',
#                  'width': 315},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'master768',
#                  'height': 512,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'master768',
#                  'subtype': 'master768',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-master768.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbStandard',
#                  'height': 75,
#                  'legacy': {'thumbnail': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-thumbStandard.jpg',
#                             'thumbnailheight': 75,
#                             'thumbnailwidth': 75},
#                  'rank': 0,
#                  'subType': 'thumbnail',
#                  'subtype': 'thumbnail',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-thumbStandard.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallThumb',
#                  'subtype': 'blogSmallThumb',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-blogSmallThumb.jpg',
#                  'width': 50},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbLarge',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'thumbLarge',
#                  'subtype': 'thumbLarge',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-thumbLarge.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare168',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare168',
#                  'subtype': 'smallSquare168',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-smallSquare168.jpg',
#                  'width': 168},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'smallSquare252',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'smallSquare252',
#                  'subtype': 'smallSquare252',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-smallSquare252.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square320',
#                  'height': 320,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square320',
#                  'subtype': 'square320',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-square320.jpg',
#                  'width': 320},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'moth',
#                  'height': 151,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'moth',
#                  'subtype': 'moth',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-moth.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'filmstrip',
#                  'height': 190,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'filmstrip',
#                  'subtype': 'filmstrip',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-filmstrip.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'square640',
#                  'height': 640,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'square640',
#                  'subtype': 'square640',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-square640.jpg',
#                  'width': 640},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumSquare149',
#                  'height': 149,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumSquare149',
#                  'subtype': 'mediumSquare149',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-mediumSquare149.jpg',
#                  'width': 149},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'sfSpan',
#                  'height': 263,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'sfSpan',
#                  'subtype': 'sfSpan',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-sfSpan.jpg',
#                  'width': 395},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontal375',
#                  'height': 250,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontal375',
#                  'subtype': 'largeHorizontal375',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-largeHorizontal375.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeHorizontalJumbo',
#                  'height': 683,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeHorizontalJumbo',
#                  'subtype': 'largeHorizontalJumbo',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-largeHorizontalJumbo.jpg',
#                  'width': 1024},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'horizontalMediumAt2X',
#                  'height': 2648,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'horizontalMediumAt2X',
#                  'subtype': 'horizontalMediumAt2X',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-horizontalMediumAt2X.jpg',
#                  'width': 3972},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpLarge',
#                  'height': 288,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpLarge',
#                  'subtype': 'hpLarge',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-hpLarge.jpg',
#                  'width': 511},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen573',
#                  'height': 322,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen573',
#                  'subtype': 'largeWidescreen573',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-largeWidescreen573.jpg',
#                  'width': 573},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'largeWidescreen1050',
#                  'height': 591,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'largeWidescreen1050',
#                  'subtype': 'largeWidescreen1050',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-largeWidescreen1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'thumbWide',
#                  'height': 126,
#                  'legacy': {'wide': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-thumbWide.jpg',
#                             'wideheight': 126,
#                             'widewidth': 190},
#                  'rank': 0,
#                  'subType': 'wide',
#                  'subtype': 'wide',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-thumbWide.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoThumb',
#                  'height': 50,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoThumb',
#                  'subtype': 'videoThumb',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-videoThumb.jpg',
#                  'width': 75},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoLarge',
#                  'height': 507,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoLarge',
#                  'subtype': 'videoLarge',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-videoLarge.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo210',
#                  'height': 140,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo210',
#                  'subtype': 'mediumThreeByTwo210',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumThreeByTwo210.jpg',
#                  'width': 210},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo225',
#                  'height': 150,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo225',
#                  'subtype': 'mediumThreeByTwo225',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumThreeByTwo225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo440',
#                  'height': 293,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo440',
#                  'subtype': 'mediumThreeByTwo440',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumThreeByTwo440.jpg',
#                  'width': 440},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo252',
#                  'height': 168,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo252',
#                  'subtype': 'mediumThreeByTwo252',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumThreeByTwo252.jpg',
#                  'width': 252},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumThreeByTwo378',
#                  'height': 252,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumThreeByTwo378',
#                  'subtype': 'mediumThreeByTwo378',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumThreeByTwo378.jpg',
#                  'width': 378},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'threeByTwoLargeAt2X',
#                  'height': 2648,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'threeByTwoLargeAt2X',
#                  'subtype': 'threeByTwoLargeAt2X',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-threeByTwoLargeAt2X.jpg',
#                  'width': 3972},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'threeByTwoMediumAt2X',
#                  'height': 1000,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'threeByTwoMediumAt2X',
#                  'subtype': 'threeByTwoMediumAt2X',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-threeByTwoMediumAt2X.jpg',
#                  'width': 1500},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'threeByTwoSmallAt2X',
#                  'height': 400,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'threeByTwoSmallAt2X',
#                  'subtype': 'threeByTwoSmallAt2X',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-threeByTwoSmallAt2X.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'articleInline',
#                  'height': 127,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'articleInline',
#                  'subtype': 'articleInline',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-articleInline.jpg',
#                  'width': 190},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'hpSmall',
#                  'height': 109,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'hpSmall',
#                  'subtype': 'hpSmall',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-hpSmall.jpg',
#                  'width': 163},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'blogSmallInline',
#                  'height': 101,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'blogSmallInline',
#                  'subtype': 'blogSmallInline',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-blogSmallInline.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mediumFlexible177',
#                  'height': 118,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mediumFlexible177',
#                  'subtype': 'mediumFlexible177',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mediumFlexible177.jpg',
#                  'width': 177},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSmall',
#                  'height': 281,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSmall',
#                  'subtype': 'videoSmall',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSmall.jpg',
#                  'width': 500},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoHpMedium',
#                  'height': 211,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoHpMedium',
#                  'subtype': 'videoHpMedium',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoHpMedium.jpg',
#                  'width': 375},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine600',
#                  'height': 338,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine600',
#                  'subtype': 'videoSixteenByNine600',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine600.jpg',
#                  'width': 600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine540',
#                  'height': 304,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine540',
#                  'subtype': 'videoSixteenByNine540',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine540.jpg',
#                  'width': 540},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine495',
#                  'height': 278,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine495',
#                  'subtype': 'videoSixteenByNine495',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine495.jpg',
#                  'width': 495},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine390',
#                  'height': 219,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine390',
#                  'subtype': 'videoSixteenByNine390',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine390.jpg',
#                  'width': 390},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine1050',
#                  'height': 591,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine1050',
#                  'subtype': 'videoSixteenByNine1050',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine1050.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine480',
#                  'height': 270,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine480',
#                  'subtype': 'videoSixteenByNine480',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine480.jpg',
#                  'width': 480},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine310',
#                  'height': 174,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine310',
#                  'subtype': 'videoSixteenByNine310',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine310.jpg',
#                  'width': 310},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine225',
#                  'height': 126,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine225',
#                  'subtype': 'videoSixteenByNine225',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine225.jpg',
#                  'width': 225},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine96',
#                  'height': 54,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine96',
#                  'subtype': 'videoSixteenByNine96',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine96.jpg',
#                  'width': 96},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine3000',
#                  'height': 1688,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine3000',
#                  'subtype': 'videoSixteenByNine3000',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine3000.jpg',
#                  'width': 3000},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine768',
#                  'height': 432,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine768',
#                  'subtype': 'videoSixteenByNine768',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine768.jpg',
#                  'width': 768},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNine150',
#                  'height': 84,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNine150',
#                  'subtype': 'videoSixteenByNine150',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNine150.jpg',
#                  'width': 150},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoSixteenByNineJumbo1600',
#                  'height': 900,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoSixteenByNineJumbo1600',
#                  'subtype': 'videoSixteenByNineJumbo1600',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-videoSixteenByNineJumbo1600.jpg',
#                  'width': 1600},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'miniMoth',
#                  'height': 70,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'miniMoth',
#                  'subtype': 'miniMoth',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-miniMoth.jpg',
#                  'width': 151},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'windowsTile336H',
#                  'height': 336,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'windowsTile336H',
#                  'subtype': 'windowsTile336H',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-windowsTile336H.jpg',
#                  'width': 694},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven1305',
#                  'height': 609,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven1305',
#                  'subtype': 'videoFifteenBySeven1305',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-videoFifteenBySeven1305.jpg',
#                  'width': 1305},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'videoFifteenBySeven2610',
#                  'height': 1218,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'videoFifteenBySeven2610',
#                  'subtype': 'videoFifteenBySeven2610',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-videoFifteenBySeven2610.jpg',
#                  'width': 2610},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'facebookJumbo',
#                  'height': 550,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'facebookJumbo',
#                  'subtype': 'facebookJumbo',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-facebookJumbo.jpg',
#                  'width': 1050},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch308',
#                  'height': 348,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch308',
#                  'subtype': 'watch308',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-watch308.jpg',
#                  'width': 312},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'watch268',
#                  'height': 304,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'watch268',
#                  'subtype': 'watch268',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-watch268.jpg',
#                  'width': 272},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'verticalTwoByThree735',
#                  'height': 1103,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'verticalTwoByThree735',
#                  'subtype': 'verticalTwoByThree735',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/16china-virus-1-verticalTwoByThree735.jpg',
#                  'width': 735},
#                 {'caption': None,
#                  'credit': None,
#                  'crop_name': 'mobileMasterAt3x',
#                  'height': 1200,
#                  'legacy': {},
#                  'rank': 0,
#                  'subType': 'mobileMasterAt3x',
#                  'subtype': 'mobileMasterAt3x',
#                  'type': 'image',
#                  'url': 'images/2020/01/16/world/16china-virus-1/merlin_166979457_2035af57-d65d-48a9-91cc-62ad9bf0d747-mobileMasterAt3x.jpg',
#                  'width': 1800}],
#  'news_desk': 'Foreign',
#  'print_page': '8',
#  'print_section': 'A',
#  'pub_date': '2020-01-16T03:29:27+0000',
#  'section_name': 'World',
#  'snippet': 'The two new patients will add to fears that the virus will spread '
#             'further outside China’s borders.',
#  'source': 'The New York Times',
#  'subsection_name': 'Asia Pacific',
#  'type_of_material': 'News',
#  'uri': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#  'web_url': 'https://www.nytimes.com/2020/01/15/world/asia/coronavirus-japan-china.html',
#  'word_count': 1172}

# %%
def get_articles(begin_date='20200101', end_date='20221001', sort='oldest'):
    
    temp_list = []    
    requestHeaders = {"Accept": "application/json"}
    
    
    for i in range(101):
        url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date={begin_date}&end_date={end_date}&fq=headline%3A(%22covid%22%20%22coronavirus%22)&page={i}&sort={sort}&api-key={KEY}"
        
        try:
            response = requests.get(url, headers=requestHeaders).json()
            response_list = response['response']['docs']
            
            try:
                for j in response_list:
                    temp_list.append(j)
                    
            except:
                break
            
            time.sleep(6)
            
        except:
            break

    return temp_list

# %%
def get_articles():
    
    begin_date_list_2020 = ['20200101', '20200201', '20200301', '20200401', '20200501', '20200601', '20200701', '20200801', '20200901', '20201001', '20201101', '20201201']
    begin_date_list_2021 = ['20210101', '20210201', '20210301', '20210401', '20210501', '20210601', '20210701', '20210801', '20210901', '20211001', '20211101', '20211201']
    begin_date_list_2022 = ['20220101', '20220201', '20220301', '20220401', '20220501', '20220601', '20220701', '20220801', '20220901', '20221001', '20221101', '20221201']    
    begin_date_list = begin_date_list_2020 + begin_date_list_2021 + begin_date_list_2022

    end_date_list_2020 = ['20200131', '20200229', '20200331', '20200430', '20200531', '20200630', '20200731', '20200831', '20200930', '20201031', '20201130', '20201231']
    end_date_list_2021 = ['20210131', '20210228', '20210331', '20210430', '20210531', '20210630', '20210731', '20210831', '20210930', '20211031', '20211130', '20211231']
    end_date_list_2022 = ['20220131', '20220228', '20220331', '20220430', '20220531', '20220630', '20220731', '20220831', '20220930', '20221031', '20221130', '20221231']    
    end_date_list = end_date_list_2020 + end_date_list_2021 + end_date_list_2022
    
    results_list = []    
    requestHeaders = {"Accept": "application/json"}
    
    for i in range(len(begin_date_list_2020)):
        for j in range(101):
            url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date={begin_date_list_2020[i]}&end_date={end_date_list_2020[i]}&fq=headline%3A(%22covid%22%20%22coronavirus%22)&page={j}&sort=oldest&api-key={KEY}"
            
            try:
                response = requests.get(url, headers=requestHeaders).json()
                response_list = response['response']['docs']
                
                for k in response_list:
                    results_list.append(k)                        
                
                time.sleep(6)
                
            except:
                break

    return results_list

# %%
list_2020 = get_articles()
len(list_2020)
# Out:
# 4606

# %%
list_2020_clean = list_2020.copy()

for i in list_2020_clean:
    i.pop('multimedia', None)
    
list_2020_clean
# Out:
# [{'abstract': 'The two new patients will add to fears that the virus will spread further outside China’s borders.',
#   'web_url': 'https://www.nytimes.com/2020/01/15/world/asia/coronavirus-japan-china.html',
#   'snippet': 'The two new patients will add to fears that the virus will spread further outside China’s borders.',
#   'lead_paragraph': 'BEIJING — Thailand and Japan each reported new cases of a coronavirus that has left two people dead and at least 40 sick in China, adding to concerns about the spread of the virus beyond Chinese borders ahead of a major holiday. ',
#   'print_section': 'A',
#   'print_page': '8',
#   'source': 'The New York Times',
#   'headline': {'main': 'Japan and Thailand Confirm New Cases of Chinese Coronavirus',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Japan Confirms Case of New Coronavirus; Patient Had Visited China',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Viruses',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 2, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Japan', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Thailand', 'rank': 5, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Pneumonia', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2020-01-16T03:29:27+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Sui-Lee Wee',
#    'person': [{'firstname': 'Sui-lee',
#      'middlename': None,
#      'lastname': 'Wee',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#   'word_count': 1172,
#   'uri': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3'},
#  {'abstract': 'Passengers from Wuhan, China, will be screened at J.F.K. beginning Friday night, and in San Francisco and Los Angeles starting on Saturday.',
#   'web_url': 'https://www.nytimes.com/2020/01/17/health/china-coronavirus-airport-screening.html',
#   'snippet': 'Passengers from Wuhan, China, will be screened at J.F.K. beginning Friday night, and in San Francisco and Los Angeles starting on Saturday.',
#   'lead_paragraph': 'Airports in New York, San Francisco and Los Angeles will begin screening passengers arriving from Wuhan, China, for infection with a mysterious respiratory virus that has killed two people and sickened at least 45 overseas, the Centers for Disease Control and Prevention announced on Friday.',
#   'print_section': 'A',
#   'print_page': '10',
#   'source': 'The New York Times',
#   'headline': {'main': 'Three U.S. Airports to Check Passengers for a Deadly Chinese Coronavirus',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'U.S. Airports Will Screen China Flights For Infection',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Airport Security', 'rank': 3, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Kennedy International Airport (Queens, NY)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Los Angeles International Airport',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'San Francisco International Airport',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Centers for Disease Control and Prevention',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Los Angeles (Calif)',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'San Francisco (Calif)',
#     'rank': 9,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'New York City', 'rank': 10, 'major': 'N'},
#    {'name': 'subject', 'value': 'Viruses', 'rank': 11, 'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 12, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 13,
#     'major': 'N'}],
#   'pub_date': '2020-01-17T19:00:08+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Denise Grady',
#    'person': [{'firstname': 'Denise',
#      'middlename': None,
#      'lastname': 'Grady',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/deeaba82-0dcb-5fa0-9f69-e6c1dd3aa2c4',
#   'word_count': 841,
#   'uri': 'nyt://article/deeaba82-0dcb-5fa0-9f69-e6c1dd3aa2c4'},
#  {'abstract': 'A top Chinese government-appointed expert says a mysterious respiratory illness that has killed at least four people can be transmitted by humans, heightening concern about the outbreak.',
#   'web_url': 'https://www.nytimes.com/2020/01/20/world/asia/coronavirus-china-symptoms.html',
#   'snippet': 'A top Chinese government-appointed expert says a mysterious respiratory illness that has killed at least four people can be transmitted by humans, heightening concern about the outbreak.',
#   'lead_paragraph': 'WUHAN, China — The mysterious coronavirus that has killed at least four people and sickened more than 200 in China is capable of spreading from person to person, a prominent Chinese scientist said on Monday, adding to fears of a broader epidemic.',
#   'print_section': 'A',
#   'print_page': '10',
#   'source': 'The New York Times',
#   'headline': {'main': 'China Confirms New Coronavirus Spreads From Humans to Humans',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'China Says New Virus Can Be Spread by Humans',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Viruses', 'rank': 3, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Beijing (China)', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Seoul (South Korea)',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Bangkok (Thailand)',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Japan', 'rank': 9, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 10, 'major': 'N'}],
#   'pub_date': '2020-01-20T10:59:15+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Javier C. Hernández and Austin Ramzy',
#    'person': [{'firstname': 'Javier',
#      'middlename': 'C.',
#      'lastname': 'Hernández',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Austin',
#      'middlename': None,
#      'lastname': 'Ramzy',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/d6e895ce-f684-5e05-b5d6-ed00d833c684',
#   'word_count': 1320,
#   'uri': 'nyt://article/d6e895ce-f684-5e05-b5d6-ed00d833c684'},
#  {'abstract': 'The new virus has killed at least nine and infected more than 400 people in China, with confirmed cases in the United States, Taiwan, Thailand, Japan and South Korea.',
#   'web_url': 'https://www.nytimes.com/2020/01/21/world/asia/china-coronavirus-wuhan.html',
#   'snippet': 'The new virus has killed at least nine and infected more than 400 people in China, with confirmed cases in the United States, Taiwan, Thailand, Japan and South Korea.',
#   'lead_paragraph': 'WUHAN, China — Facing growing pressure to contain a deadly viral outbreak that has spread halfway around the world, China’s ruling Communist Party raced on Tuesday to confront the disease, slapping restrictions on the city where it started and warning that anyone who hides infections will be “forever nailed to history’s pillar of shame.”',
#   'print_section': 'A',
#   'print_page': '1',
#   'source': 'The New York Times',
#   'headline': {'main': 'The Test a Deadly Coronavirus Outbreak Poses to China’s Leadership',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'As Infections Mount, Virus Poses Test for China',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 2, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Politics and Government',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 5, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'SARS (Severe Acute Respiratory Syndrome)',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Airport Security', 'rank': 9, 'major': 'N'},
#    {'name': 'subject', 'value': 'Airports', 'rank': 10, 'major': 'N'}],
#   'pub_date': '2020-01-21T08:26:13+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Javier C. Hernández',
#    'person': [{'firstname': 'Javier',
#      'middlename': 'C.',
#      'lastname': 'Hernández',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/4f2c6360-3926-5e87-bd74-6fa8916e5d08',
#   'word_count': 1471,
#   'uri': 'nyt://article/4f2c6360-3926-5e87-bd74-6fa8916e5d08'},
#  {'abstract': "Here's what you need to know.",
#   'web_url': 'https://www.nytimes.com/2020/01/21/briefing/impeachment-trial-davos-coronavirus.html',
#   'snippet': "Here's what you need to know.",
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Impeachment Trial, Davos, Coronavirus: Your Tuesday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-01-21T10:22:53+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Chris Stanford',
#    'person': [{'firstname': 'Chris',
#      'middlename': None,
#      'lastname': 'Stanford',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/6468ef74-43a0-5640-9d89-2e838129da4d',
#   'word_count': 1208,
#   'uri': 'nyt://article/6468ef74-43a0-5640-9d89-2e838129da4d'},
#  {'abstract': 'The spread of the virus from China is bad news for Kim Jong-un; North Korea depends on Chinese tourists for cash.',
#   'web_url': 'https://www.nytimes.com/2020/01/21/world/asia/coronavirus-china-north-korea-tourism-ban.html',
#   'snippet': 'The spread of the virus from China is bad news for Kim Jong-un; North Korea depends on Chinese tourists for cash.',
#   'lead_paragraph': 'SEOUL, South Korea — North Korea has temporarily barred foreign tourists as a protection against the mysterious virus from China that has killed at least nine people and sickened more than 400, a leading tour operator reported on Tuesday.',
#   'source': 'The New York Times',
#   'headline': {'main': 'North Korea Bans Foreign Tourists Over Coronavirus, Tour Operator Says',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Virus Prompts North Koreans To Bar Tourists',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Embargoes and Sanctions',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Young Pioneer Tours (YPT Group Ltd)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'North Korea', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 4, 'major': 'N'},
#    {'name': 'subject', 'value': 'Viruses', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2020-01-21T18:16:46+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Choe Sang-Hun',
#    'person': [{'firstname': 'Choe',
#      'middlename': None,
#      'lastname': 'Sang-Hun',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/fc655334-e191-520f-a32e-a19cebe242a2',
#   'word_count': 402,
#   'uri': 'nyt://article/fc655334-e191-520f-a32e-a19cebe242a2'},
#  {'abstract': 'A man in Washington State is infected with a new respiratory virus. Federal officials plan to expand screenings for the infection at major airports.',
#   'web_url': 'https://www.nytimes.com/2020/01/21/health/cdc-coronavirus.html',
#   'snippet': 'A man in Washington State is infected with a new respiratory virus. Federal officials plan to expand screenings for the infection at major airports.',
#   'lead_paragraph': 'A man in Washington State is infected with the Wuhan coronavirus, the first confirmed case in the United States of a mysterious respiratory infection that has killed at least six people and sickened hundreds more in Asia, the Centers for Disease Control and Prevention announced on Tuesday.',
#   'print_section': 'A',
#   'print_page': '10',
#   'source': 'The New York Times',
#   'headline': {'main': 'First Patient With Wuhan Coronavirus Is Identified in the U.S.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'First Patient With the Mysterious Illness Is Identified in the U.S.',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 2, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Centers for Disease Control and Prevention',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Snohomish County (Wash)',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Airport Security', 'rank': 8, 'major': 'N'},
#    {'name': 'subject', 'value': 'Airports', 'rank': 9, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'your-feed-science',
#     'rank': 10,
#     'major': 'N'}],
#   'pub_date': '2020-01-21T18:31:19+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Roni Caryn Rabin',
#    'person': [{'firstname': 'Roni',
#      'middlename': 'Caryn',
#      'lastname': 'Rabin',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/e38037e5-bbfb-56bd-8c4d-e0f201b8fae9',
#   'word_count': 1096,
#   'uri': 'nyt://article/e38037e5-bbfb-56bd-8c4d-e0f201b8fae9'},
#  {'abstract': 'A respiratory virus that originated in China has infected more than 900,000 people worldwide, with at least 200,000 cases in the United States.',
#   'web_url': 'https://www.nytimes.com/article/what-is-coronavirus.html',
#   'snippet': 'A respiratory virus that originated in China has infected more than 900,000 people worldwide, with at least 200,000 cases in the United States.',
#   'lead_paragraph': 'A novel respiratory virus that originated in Wuhan, China, last December has spread to six continents. Hundreds of thousands have been infected, at least 20,000 people have died and the spread of the coronavirus was called a pandemic by the World Health Organization in March. ',
#   'print_section': 'D',
#   'print_page': '1',
#   'source': 'The New York Times',
#   'headline': {'main': 'The Coronavirus: What Scientists Have Learned So Far',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'A Deadly New Contagion',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Quarantines', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 7, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Snohomish County (Wash)',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'United States', 'rank': 9, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'your-feed-healthcare',
#     'rank': 10,
#     'major': 'N'}],
#   'pub_date': '2020-01-21T20:06:18+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Knvul Sheikh and Roni Caryn Rabin',
#    'person': [{'firstname': 'Knvul',
#      'middlename': None,
#      'lastname': 'Sheikh',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Roni',
#      'middlename': 'Caryn',
#      'lastname': 'Rabin',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/860a5b40-4a33-5487-a250-a8fb57bea341',
#   'word_count': 1786,
#   'uri': 'nyt://article/860a5b40-4a33-5487-a250-a8fb57bea341'},
#  {'abstract': 'Here’s what you need to know.',
#   'web_url': 'https://www.nytimes.com/2020/01/21/briefing/wuhan-coronavirus-climate-change-impeachment.html',
#   'snippet': 'Here’s what you need to know.',
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan Coronavirus, Impeachment, Climate Change: Your Wednesday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-01-21T20:39:20+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Melina Delkic',
#    'person': [{'firstname': 'Melina',
#      'middlename': None,
#      'lastname': 'Delkic',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/001ad0e2-57b6-5f2a-9d56-69d1a4a95e43',
#   'word_count': 1147,
#   'uri': 'nyt://article/001ad0e2-57b6-5f2a-9d56-69d1a4a95e43'},
#  {'abstract': 'The virus has sickened tens of thousands of people in China and a number of other countries.',
#   'web_url': 'https://www.nytimes.com/interactive/2020/01/21/world/asia/china-coronavirus-maps.html',
#   'snippet': 'The virus has sickened tens of thousands of people in China and a number of other countries.',
#   'lead_paragraph': 'The virus has sickened tens of thousands of people in China and a number of other countries.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan Coronavirus Map: Tracking the Spread of the Outbreak',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'glocations',
#     'value': 'China',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations', 'value': 'United States', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'France', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Singapore', 'rank': 8, 'major': 'N'}],
#   'pub_date': '2020-01-21T21:37:37+0000',
#   'document_type': 'multimedia',
#   'news_desk': 'World',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By K.K. Rebecca Lai, Jin Wu, Allison McCann, Derek Watkins, Jugal K. Patel and Richard Harris',
#    'person': [{'firstname': 'K.',
#      'middlename': 'K.',
#      'lastname': 'Rebecca',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Interactive Feature',
#   '_id': 'nyt://interactive/542bc9e7-31f7-5128-8909-8dd39a5ecf9c',
#   'word_count': 0,
#   'uri': 'nyt://interactive/542bc9e7-31f7-5128-8909-8dd39a5ecf9c'},
#  {'abstract': 'Here’s what you need to know.',
#   'web_url': 'https://www.nytimes.com/2020/01/22/briefing/coronavirus-davos-impeachment.html',
#   'snippet': 'Here’s what you need to know.',
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus, Davos, Impeachment: Your Wednesday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Trump-Ukraine Whistle-blower Complaint and Impeachment Inquiry',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 3, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Harry, Prince of Wales',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Markle, Meghan', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2020-01-22T05:49:40+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Mike Ives and Sofia Mitra-Thakur',
#    'person': [{'firstname': 'Mike',
#      'middlename': None,
#      'lastname': 'Ives',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Sofia',
#      'middlename': None,
#      'lastname': 'Mitra-Thakur',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/805af2c2-621a-5d90-9a97-f1a4e8f3fc6b',
#   'word_count': 1499,
#   'uri': 'nyt://article/805af2c2-621a-5d90-9a97-f1a4e8f3fc6b'},
#  {'abstract': 'The sudden restrictions — announced after the official death toll nearly doubled — could upend the travel plans of millions of Chinese citizens, who travel in huge numbers during the Lunar New Year holiday.',
#   'web_url': 'https://www.nytimes.com/2020/01/22/world/asia/china-coronavirus-travel.html',
#   'snippet': 'The sudden restrictions — announced after the official death toll nearly doubled — could upend the travel plans of millions of Chinese citizens, who travel in huge numbers during the Lunar New Year holiday.',
#   'lead_paragraph': 'BEIJING — Chinese authorities on Thursday morning closed off Wuhan — a city of more than 11 million people and the epicenter of a pneumonia-like virus that has spread halfway around the world —\xa0by canceling planes and trains leaving the city, and suspending buses, subways and ferries within it.',
#   'print_section': 'A',
#   'print_page': '1',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan, Center of Coronavirus Outbreak, Is Being Cut Off by Chinese Authorities',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'China Closes Off City at Center of Virus Outbreak',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Viruses', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Politics and Government',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Lunar New Year', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 7, 'major': 'N'},
#    {'name': 'subject', 'value': 'Travel Warnings', 'rank': 8, 'major': 'N'}],
#   'pub_date': '2020-01-22T07:16:59+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Amy Qin and Vivian Wang',
#    'person': [{'firstname': 'Amy',
#      'middlename': None,
#      'lastname': 'Qin',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Vivian',
#      'middlename': None,
#      'lastname': 'Wang',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/f1607a68-3095-5155-8b4c-a4b7bfccc808',
#   'word_count': 1524,
#   'uri': 'nyt://article/f1607a68-3095-5155-8b4c-a4b7bfccc808'},
#  {'abstract': "Here's what you need to know.",
#   'web_url': 'https://www.nytimes.com/2020/01/22/briefing/impeachment-coronavirus-jeff-bezos.html',
#   'snippet': "Here's what you need to know.",
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Impeachment, Coronavirus, Terry Jones: Your Wednesday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-01-22T10:45:52+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Chris Stanford',
#    'person': [{'firstname': 'Chris',
#      'middlename': None,
#      'lastname': 'Stanford',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/992e1193-e044-55b0-9213-849d433f9503',
#   'word_count': 1403,
#   'uri': 'nyt://article/992e1193-e044-55b0-9213-849d433f9503'},
#  {'abstract': 'Here’s what you need to know.',
#   'web_url': 'https://www.nytimes.com/2020/01/22/briefing/wuhan-coronavirus-brexit-australian-open.html',
#   'snippet': 'Here’s what you need to know.',
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan Coronavirus, Brexit, Australian Open: Your Thursday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-01-22T21:27:31+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Melina Delkic and Andrea Kannapell',
#    'person': [{'firstname': 'Melina',
#      'middlename': None,
#      'lastname': 'Delkic',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Andrea',
#      'middlename': None,
#      'lastname': 'Kannapell',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/0e0a6fe1-5d39-5ab9-9328-19714074791a',
#   'word_count': 1435,
#   'uri': 'nyt://article/0e0a6fe1-5d39-5ab9-9328-19714074791a'},
#  {'abstract': 'Health leaders in Washington State have been working to monitor at least 16 people who may have been in close contact with the man who flew in from China.',
#   'web_url': 'https://www.nytimes.com/2020/01/22/us/coronavirus-seattle-washington.html',
#   'snippet': 'Health leaders in Washington State have been working to monitor at least 16 people who may have been in close contact with the man who flew in from China.',
#   'lead_paragraph': 'SEATTLE — Health officials scrambled on Wednesday to contact more than a dozen people who may have been exposed to the United States’ first case of the Wuhan coronavirus, even as regulators sought to assure the public there was little risk from an illness that has rapidly spread across Asia, killing at least 17 people.',
#   'source': 'The New York Times',
#   'headline': {'main': 'A Scramble to Retrace the Steps of the First Wuhan Coronavirus Case in the U.S.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 2, 'major': 'N'},
#    {'name': 'glocations',
#     'value': 'Snohomish County (Wash)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2020-01-23T01:23:43+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'U.S.',
#   'byline': {'original': 'By Mike Baker',
#    'person': [{'firstname': 'Mike',
#      'middlename': None,
#      'lastname': 'Baker',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/5a419b5f-7fbf-5c56-8475-b61a38a26189',
#   'word_count': 847,
#   'uri': 'nyt://article/5a419b5f-7fbf-5c56-8475-b61a38a26189'},
#  {'abstract': 'At least 25 people have died and more than 800 have been sickened by the mysterious illness, health officials said. The travel restrictions imposed on Wuhan were extended to at least four more cities.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/world/asia/china-coronavirus.html',
#   'snippet': 'At least 25 people have died and more than 800 have been sickened by the mysterious illness, health officials said. The travel restrictions imposed on Wuhan were extended to at least four more cities.',
#   'lead_paragraph': 'This briefing has ended. Read about developments in the coronavirus outbreak here. ',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus Death Toll Climbs in China, and a Lockdown Widens',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Hospitals', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'SARS (Severe Acute Respiratory Syndrome)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Lunar New Year', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 6, 'major': 'N'}],
#   'pub_date': '2020-01-23T05:10:24+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By The New York Times',
#    'person': [],
#    'organization': 'The New York Times'},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/5beb2af1-57f2-56f5-b7a9-2c7e5c64c4e8',
#   'word_count': 3378,
#   'uri': 'nyt://article/5beb2af1-57f2-56f5-b7a9-2c7e5c64c4e8'},
#  {'abstract': 'The Chinese city of 11 million embodies the country’s surge from grinding poverty to industrial powerhouse.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/world/asia/wuhan-coronavirus.html',
#   'snippet': 'The Chinese city of 11 million embodies the country’s surge from grinding poverty to industrial powerhouse.',
#   'lead_paragraph': 'If Wuhan could be compared to an American city, it might be Pittsburgh — a much bigger, much hotter Pittsburgh.',
#   'print_section': 'A',
#   'print_page': '6',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan Beyond the Coronavirus: Steel, Cars and Spicy Noodles',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'China’s Pittsburgh Is Known For Steel, Cars and Noodles',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'glocations',
#     'value': 'China',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Economic Conditions and Trends',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Automobiles', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2020-01-23T06:25:18+0000',
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Carlos Tejada',
#    'person': [{'firstname': 'Carlos',
#      'middlename': None,
#      'lastname': 'Tejada',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/4c0e1a36-277b-5174-a6a9-a949d90f2586',
#   'word_count': 527,
#   'uri': 'nyt://article/4c0e1a36-277b-5174-a6a9-a949d90f2586'},
#  {'abstract': 'As China released details about the first 17 people who have died in the outbreak, a well-known SARS expert raised an alarm about the virus’s spread, saying he felt “powerless.”',
#   'web_url': 'https://www.nytimes.com/2020/01/23/world/asia/coronavirus-victims-wuhan.html',
#   'snippet': 'As China released details about the first 17 people who have died in the outbreak, a well-known SARS expert raised an alarm about the virus’s spread, saying he felt “powerless.”',
#   'lead_paragraph': 'HONG KONG — When the man finally went to a hospital, he had been sick for a week. It was Dec. 26, and Mr. Zeng, 61, was weak with a cough. He got worse. A day later he was transferred to intensive care, and on Dec. 30 he was put on a ventilator to try to keep him alive.',
#   'print_section': 'A',
#   'print_page': '7',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus Deaths Are So Far Mostly Older Men, Many With Previous Health Issues',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Most Deaths From Virus So Far Are Chronically Ill Older Men',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Politics and Government',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2020-01-23T08:24:48+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Austin Ramzy',
#    'person': [{'firstname': 'Austin',
#      'middlename': None,
#      'lastname': 'Ramzy',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/5869635b-c2e0-51f8-83f1-6bb75d020713',
#   'word_count': 893,
#   'uri': 'nyt://article/5869635b-c2e0-51f8-83f1-6bb75d020713'},
#  {'abstract': 'Here are the latest images as the country confronts a major public health crisis.',
#   'web_url': 'https://www.nytimes.com/2020/01/25/world/asia/china-coronavirus-photos.html',
#   'snippet': 'Here are the latest images as the country confronts a major public health crisis.',
#   'lead_paragraph': 'The spread of a mysterious respiratory virus has prompted the authorities to limit travel in cities in China, including Wuhan, where the disease was first found last month. It has since spread across the nation and to at least 10 other countries.',
#   'source': 'The New York Times',
#   'headline': {'main': 'China’s Battle With a Deadly Coronavirus, in Photos',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Lunar New Year', 'rank': 2, 'major': 'N'},
#    {'name': 'subject', 'value': 'Transit Systems', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Stations and Terminals (Passenger)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Airport Security', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2020-01-23T11:50:06+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By The New York Times',
#    'person': [],
#    'organization': 'The New York Times'},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/91e8dfc1-c8db-5634-8930-ad40fa7c9283',
#   'word_count': 651,
#   'uri': 'nyt://article/91e8dfc1-c8db-5634-8930-ad40fa7c9283'},
#  {'abstract': 'As China closes off cities affected by the growing viral outbreak, business leaders at the World Economic Forum fear a replay of the SARS epidemic.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/business/dealbook/coronavirus-davos-world-economic-forum.html',
#   'snippet': 'As China closes off cities affected by the growing viral outbreak, business leaders at the World Economic Forum fear a replay of the SARS epidemic.',
#   'lead_paragraph': 'Hello from Davos, Switzerland, where business leaders are worried about the growing coronavirus outbreak. More below. (Want this in your inbox each morning? Sign up here.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Fears Over New Coronavirus Grip Davos',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Bezos, Jeffrey P',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 2,
#     'major': 'N'}],
#   'pub_date': '2020-01-23T11:50:57+0000',
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'subsection_name': 'DealBook',
#   'byline': {'original': None, 'person': [], 'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/0419460d-f664-5ff4-8c41-7be3b90d324b',
#   'word_count': 1523,
#   'uri': 'nyt://article/0419460d-f664-5ff4-8c41-7be3b90d324b'},
#  {'abstract': 'The number of cases outside China is small, and the disease does not seem to be spreading within other countries.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/health/china-virus-who-emergency.html',
#   'snippet': 'The number of cases outside China is small, and the disease does not seem to be spreading within other countries.',
#   'lead_paragraph': 'The World Health Organization on Thursday decided not to declare the Wuhan coronavirus outbreak a global emergency, despite the spread of the dangerous respiratory infection from China to at least five other countries.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus Is Spreading, but W.H.O. Says It’s Not a Global Emergency',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'World Health Organization',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'SARS (Severe Acute Respiratory Syndrome)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 6, 'major': 'N'},
#    {'name': 'subject', 'value': 'your-feed-science', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2020-01-23T18:27:57+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Denise Grady',
#    'person': [{'firstname': 'Denise',
#      'middlename': None,
#      'lastname': 'Grady',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/39399da0-4c86-59b8-a581-2a259df7fb39',
#   'word_count': 935,
#   'uri': 'nyt://article/39399da0-4c86-59b8-a581-2a259df7fb39'},
#  {'abstract': 'Health officials said they were keeping the Texas A&M student, who had traveled to China, isolated at home.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/us/united-states-coronavirus-cases.html',
#   'snippet': 'Health officials said they were keeping the Texas A&M student, who had traveled to China, isolated at home.',
#   'lead_paragraph': 'SEATTLE — A Texas A&M University student was being isolated at home on Thursday as health officials said they were examining whether he could be the second known case of Wuhan coronavirus in the United States.',
#   'print_section': 'A',
#   'print_page': '7',
#   'source': 'The New York Times',
#   'headline': {'main': 'Texas Student May Have Wuhan Coronavirus, as Dozens in U.S. Are Monitored',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Texas Student Is Monitored After a Trip',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Travel Warnings', 'rank': 3, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 4, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Texas', 'rank': 5, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Seattle (Wash)', 'rank': 6, 'major': 'N'}],
#   'pub_date': '2020-01-23T20:04:43+0000',
#   'document_type': 'article',
#   'news_desk': 'National',
#   'section_name': 'U.S.',
#   'byline': {'original': 'By Mike Baker',
#    'person': [{'firstname': 'Mike',
#      'middlename': None,
#      'lastname': 'Baker',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/f8da0327-f6ce-55eb-90be-2d891b15e9ad',
#   'word_count': 576,
#   'uri': 'nyt://article/f8da0327-f6ce-55eb-90be-2d891b15e9ad'},
#  {'abstract': 'Here’s what you need to know.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/briefing/wuhan-coronavirus-australia-fires-myanmar.html',
#   'snippet': 'Here’s what you need to know.',
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Wuhan Coronavirus, Australia Firefighters, Myanmar Ruling: Your Friday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-01-23T21:03:12+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Melina Delkic',
#    'person': [{'firstname': 'Melina',
#      'middlename': None,
#      'lastname': 'Delkic',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/3f8fd5f4-72a9-52db-ba9a-789d8c6c15aa',
#   'word_count': 1151,
#   'uri': 'nyt://article/3f8fd5f4-72a9-52db-ba9a-789d8c6c15aa'},
#  {'abstract': 'They may help, but experts say it’s more important to wash your hands.',
#   'web_url': 'https://www.nytimes.com/2020/01/23/health/coronavirus-surgical-masks.html',
#   'snippet': 'They may help, but experts say it’s more important to wash your hands.',
#   'lead_paragraph': 'Chinese authorities have encouraged people in the city of Wuhan to wear surgical masks in public to help curb the spread of the new coronavirus.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Many in China Wear Them, but Do Masks Block Coronavirus?',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Protective Clothing and Gear',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Masks', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Respiratory Diseases',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 5, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Centers for Disease Control and Prevention',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 7, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Wuhan (China)', 'rank': 8, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Hygiene and Cleanliness',
#     'rank': 9,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'your-feed-science', 'rank': 10, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'your-feed-healthcare',
#     'rank': 11,
#     'major': 'N'}],
#   'pub_date': '2020-01-23T23:02:41+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Roni Caryn Rabin',
#    'person': [{'firstname': 'Roni',
#      'middlename': 'Caryn',
#      'lastname': 'Rabin',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/341782ec-1c5e-554a-8c1b-27664c8e4e6e',
#   'word_count': 592,
#   'uri': 'nyt://article/341782ec-1c5e-554a-8c1b-27664c8e4e6e'},
#  {'abstract': 'The outbreak of a dangerous respiratory virus in China is putting a strain on hospital staff and medical resources.',
#   'web_url': 'https://www.nytimes.com/video/world/asia/100000006936419/coronavirus-china-wuhan.html',
#   'snippet': 'The outbreak of a dangerous respiratory virus in China is putting a strain on hospital staff and medical resources.',
#   'lead_paragraph': 'The outbreak of a dangerous respiratory virus in China is putting a strain on hospital staff and medical resources.',
# ...
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Funerals and Memorials',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Quarantines', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Deaths (Fatalities)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Cemeteries', 'rank': 5, 'major': 'N'},
#    {'name': 'subject', 'value': 'Epidemics', 'rank': 6, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Italy', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2020-03-16T17:38:07+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Europe',
#   'byline': {'original': 'By Jason Horowitz and Emma Bubola',
#    'person': [{'firstname': 'Jason',
#      'middlename': None,
#      'lastname': 'Horowitz',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Emma',
#      'middlename': None,
#      'lastname': 'Bubola',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/055a74a2-ae2d-5b2c-b7d4-ac296e9ddc19',
#   'word_count': 1563,
#   'uri': 'nyt://article/055a74a2-ae2d-5b2c-b7d4-ac296e9ddc19'},
#  {'abstract': 'The site from Google’s sister company, Verily, was rolled out to two Northern California counties in hopes of guiding people to local virus testing.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/technology/coronavirus-testing-website-google.html',
#   'snippet': 'The site from Google’s sister company, Verily, was rolled out to two Northern California counties in hopes of guiding people to local virus testing.',
#   'lead_paragraph': 'SAN FRANCISCO — A website intended to facilitate nationwide testing for coronavirus that was promoted by President Trump in a news conference on Friday quickly reached capacity when it went live in a small pilot project late on Sunday night.',
#   'print_section': 'B',
#   'print_page': '5',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus Testing Website Goes Live and Quickly Hits Capacity',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Google Site to Screen for COVID-19 Goes Live and Causes Confusion',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Tests (Medical)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Computers and the Internet',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'organizations', 'value': 'Alphabet Inc', 'rank': 4, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Verily Life Sciences LLC',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations', 'value': 'Google Inc', 'rank': 6, 'major': 'N'},
#    {'name': 'persons', 'value': 'Pichai, Sundar', 'rank': 7, 'major': 'N'}],
#   'pub_date': '2020-03-16T17:48:52+0000',
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Technology',
#   'byline': {'original': 'By Daisuke Wakabayashi and Natasha Singer',
#    'person': [{'firstname': 'Daisuke',
#      'middlename': None,
#      'lastname': 'Wakabayashi',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Natasha',
#      'middlename': None,
#      'lastname': 'Singer',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/6686944b-4344-59b3-a646-a0889e1da50b',
#   'word_count': 995,
#   'uri': 'nyt://article/6686944b-4344-59b3-a646-a0889e1da50b'},
#  {'abstract': 'President Trump and leading health officials are now recommending closing more schools, avoiding groups of more than 10, discretionary travel, bars and restaurants.',
#   'web_url': 'https://www.nytimes.com/video/us/politics/100000007036873/trump-coronavirus.html',
#   'snippet': 'President Trump and leading health officials are now recommending closing more schools, avoiding groups of more than 10, discretionary travel, bars and restaurants.',
#   'lead_paragraph': 'President Trump and leading health officials are now recommending closing more schools, avoiding groups of more than 10, discretionary travel, bars and restaurants.',
#   'source': 'AP',
#   'headline': {'main': '‘Every One of Us Has a Critical Role’: Trump Releases New Coronavirus Guidelines',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Quarantines', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2020-03-16T19:02:36+0000',
#   'document_type': 'multimedia',
#   'news_desk': '',
#   'section_name': 'U.S.',
#   'subsection_name': 'Politics',
#   'byline': {'original': 'By The Associated Press',
#    'person': [],
#    'organization': 'The Associated Press'},
#   'type_of_material': 'Video',
#   '_id': 'nyt://video/8c673a6a-7ca8-53c8-a927-a4bf0c373d7f',
#   'word_count': 0,
#   'uri': 'nyt://video/8c673a6a-7ca8-53c8-a927-a4bf0c373d7f'},
#  {'abstract': 'Here’s what you need to know.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/briefing/coronavirus-china-economy-billie-eilish.html',
#   'snippet': 'Here’s what you need to know.',
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus, China’s Economy, Billie Eilish: Your Tuesday Briefing',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [],
#   'pub_date': '2020-03-16T19:07:05+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Melina Delkic and Jonathan Wolfe',
#    'person': [{'firstname': 'Melina',
#      'middlename': None,
#      'lastname': 'Delkic',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Jonathan',
#      'middlename': None,
#      'lastname': 'Wolfe',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/4d9870f7-b3de-5063-a550-e7fe666dbe9a',
#   'word_count': 1530,
#   'uri': 'nyt://article/4d9870f7-b3de-5063-a550-e7fe666dbe9a'},
#  {'abstract': 'Nonessential federal employees should be working from home.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/opinion/federal-workers-coronavirus.html',
#   'snippet': 'Nonessential federal employees should be working from home.',
#   'lead_paragraph': 'Stay home. Avoid crowds. Work remotely. Keep at least six feet between you and other people. As the coronavirus tightens its grip, the pleas from health experts for people to limit face-to-face contact are growing ever more pointed and urgent.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Protect Government Workers, Too, From the Coronavirus',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Shutdowns (Institutional)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Telecommuting', 'rank': 4, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Office of Management and Budget (US)',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'House of Representatives',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations', 'value': 'Senate', 'rank': 7, 'major': 'N'},
#    {'name': 'persons', 'value': 'Pelosi, Nancy', 'rank': 8, 'major': 'N'}],
#   'pub_date': '2020-03-16T19:09:30+0000',
#   'document_type': 'article',
#   'news_desk': 'Editorial',
#   'section_name': 'Opinion',
#   'byline': {'original': 'By The Editorial Board',
#    'person': [],
#    'organization': 'The Editorial Board'},
#   'type_of_material': 'Editorial',
#   '_id': 'nyt://article/081a0751-288d-5906-824b-23f27afd4e61',
#   'word_count': 870,
#   'uri': 'nyt://article/081a0751-288d-5906-824b-23f27afd4e61'},
#  {'abstract': 'Workers and owners in the city’s world-famous restaurant and bar scene reel from decision to cut off their livelihoods.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/nyregion/nyc-closing-bars-restaurants-coronavirus.html',
#   'snippet': 'Workers and owners in the city’s world-famous restaurant and bar scene reel from decision to cut off their livelihoods.',
#   'lead_paragraph': 'New York City’s renowned restaurant and nightlife industries — global destinations and trendsetters for generations — awoke Monday to a devastating new world, finding themselves all but shut down in an open-ended battle against a microscopic threat.',
#   'source': 'The New York Times',
#   'headline': {'main': '‘We’re Completely Lost’: Coronavirus Hits N.Y. Restaurants',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Restaurants', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Bars and Nightclubs',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Chefs', 'rank': 4, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Layoffs and Job Reductions',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Carmellini, Andrew', 'rank': 6, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Vongerichten, Jean-Georges',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Johnson, Joseph (JJ) (1984- )',
#     'rank': 8,
#     'major': 'N'}],
#   'pub_date': '2020-03-16T19:20:17+0000',
#   'document_type': 'article',
#   'news_desk': 'Metro',
#   'section_name': 'New York',
#   'byline': {'original': 'By Michael Wilson and Amelia Nierenberg',
#    'person': [{'firstname': 'Michael',
#      'middlename': None,
#      'lastname': 'Wilson',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Amelia',
#      'middlename': None,
#      'lastname': 'Nierenberg',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/e8ab029f-9482-58fa-be3f-652bc33e8796',
#   'word_count': 1227,
#   'uri': 'nyt://article/e8ab029f-9482-58fa-be3f-652bc33e8796'},
#  {'abstract': 'Millions of children sit home as competitions go dark, though some are trying to play limited games.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/sports/coronavirus-canceled-youth-sports.html',
#   'snippet': 'Millions of children sit home as competitions go dark, though some are trying to play limited games.',
#   'lead_paragraph': ' Little League baseball has shut down. Youth lacrosse and soccer clubs have suspended their seasons. Travel teams across all sports have been grounded. The coronavirus pandemic has done what generations of overbearing parents and coaches have failed to do: send millions of boys and girls to the sideline.',
#   'print_section': 'B',
#   'print_page': '8',
#   'source': 'The New York Times',
#   'headline': {'main': 'Tears and Disbelief as Coronavirus Cancels Youth Sports',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Boys and Girls All Suited Up  With Nowhere to Play',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Athletics and Sports',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Interscholastic Athletics',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Swimming', 'rank': 4, 'major': 'N'},
#    {'name': 'subject', 'value': 'Volleyball', 'rank': 5, 'major': 'N'},
#    {'name': 'subject', 'value': 'Wrestling', 'rank': 6, 'major': 'N'},
#    {'name': 'subject', 'value': 'Basketball', 'rank': 7, 'major': 'N'},
#    {'name': 'subject', 'value': 'Lacrosse', 'rank': 8, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Little League Baseball and Softball',
#     'rank': 9,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Aspen Institute',
#     'rank': 10,
#     'major': 'N'}],
#   'pub_date': '2020-03-16T19:40:22+0000',
#   'document_type': 'article',
#   'news_desk': 'Sports',
#   'section_name': 'Sports',
#   'byline': {'original': 'By Joe Drape and David W. Chen',
#    'person': [{'firstname': 'Joe',
#      'middlename': None,
#      'lastname': 'Drape',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'David',
#      'middlename': 'W.',
#      'lastname': 'Chen',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/ae1cbf2d-5e9a-5f79-b188-f30ca1e4e68f',
#   'word_count': 1365,
#   'uri': 'nyt://article/ae1cbf2d-5e9a-5f79-b188-f30ca1e4e68f'},
#  {'abstract': 'For every known case of coronavirus, another five to 10 cases are out there undetected, a new study suggests.',
#   'web_url': 'https://www.nytimes.com/2020/03/16/health/coronavirus-statistics-undetected.html',
#   'snippet': 'For every known case of coronavirus, another five to 10 cases are out there undetected, a new study suggests.',
#   'lead_paragraph': 'Scientists tracking the spread of the coronavirus reported on Monday that, for every confirmed case, there are most likely another five to 10 people in the community with undetected infections. These often-milder cases are, on average, about half as infectious as confirmed ones, but are responsible for nearly 80 percent of new cases, according to the report, which was based on data from China.',
#   'print_section': 'A',
#   'print_page': '12',
#   'source': 'The New York Times',
#   'headline': {'main': 'Coronavirus Is Hiding in Plain Sight',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Vast Majority Of Infections Not Detected, Scientists Say',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Shutdowns (Institutional)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Travel Warnings', 'rank': 3, 'major': 'N'},
#    {'name': 'subject', 'value': 'Tests (Medical)', 'rank': 4, 'major': 'N'}],
#   'pub_date': '2020-03-16T20:02:36+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Benedict Carey',
#    'person': [{'firstname': 'Benedict',
#      'middlename': None,
#      'lastname': 'Carey',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/809e18e9-8d7f-5179-87f1-1db2b8020996',
#   'word_count': 476,
#   'uri': 'nyt://article/809e18e9-8d7f-5179-87f1-1db2b8020996'},
#  ...]

# %%
len(list_2020_clean)
# Out:
# 4606

# %%
with open('list_2020_clean.json', 'w') as outfile:
    json.dump(list_2020_clean, outfile)

# %%
# Covid books search
url = f'https://api.nytimes.com/svc/books/v3/reviews.json?title=Covid&api-key={KEY}'

response = requests.get(url).json()

pprint(response)
# Out:
# {'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights '
#               'Reserved.',
#  'num_results': 0,
#  'results': [],
#  'status': 'OK'}

# %%
# Most popular articles
url = f'https://api.nytimes.com/svc/mostpopular/v2/viewed/30.json?api-key={KEY}'

response = requests.get(url).json()

pprint(response['results'][0])
# Out:
# {'abstract': 'Yvon Chouinard has forfeited ownership of the company he founded '
#              '49 years ago. The profits will now be used to fight climate '
#              'change.',
#  'adx_keywords': 'Global Warming;Philanthropy;Corporate Social '
#                  'Responsibility;High Net Worth Individuals;Capitalism (Theory '
#                  'and Philosophy);Content Type: Personal Profile;Fashion and '
#                  'Apparel;Mergers, Acquisitions and Divestitures;Chouinard, '
#                  'Yvon;Patagonia Inc',
#  'asset_id': 100000008485792,
#  'byline': 'By David Gelles',
#  'column': None,
#  'des_facet': ['Global Warming',
#                'Philanthropy',
#                'Corporate Social Responsibility',
#                'High Net Worth Individuals',
#                'Capitalism (Theory and Philosophy)',
#                'Content Type: Personal Profile',
#                'Fashion and Apparel',
#                'Mergers, Acquisitions and Divestitures'],
#  'eta_id': 0,
#  'geo_facet': [],
#  'id': 100000008485792,
#  'media': [{'approved_for_syndication': 1,
#             'caption': '',
#             'copyright': 'Natalie Behring for The New York Times',
#             'media-metadata': [{'format': 'Standard Thumbnail',
#                                 'height': 75,
#                                 'url': 'https://static01.nyt.com/images/2022/09/12/climate/00cli-patagonia-promo/00cli-patagonia-promo-thumbStandard.jpg',
#                                 'width': 75},
#                                {'format': 'mediumThreeByTwo210',
#                                 'height': 140,
#                                 'url': 'https://static01.nyt.com/images/2022/09/12/climate/00cli-patagonia-promo/00cli-patagonia-promo-mediumThreeByTwo210.jpg',
#                                 'width': 210},
#                                {'format': 'mediumThreeByTwo440',
#                                 'height': 293,
#                                 'url': 'https://static01.nyt.com/images/2022/09/12/climate/00cli-patagonia-promo/00cli-patagonia-promo-mediumThreeByTwo440.jpg',
#                                 'width': 440}],
#             'subtype': 'photo',
#             'type': 'image'}],
#  'nytdsection': 'climate',
#  'org_facet': ['Patagonia Inc'],
#  'per_facet': ['Chouinard, Yvon'],
#  'published_date': '2022-09-14',
#  'section': 'Climate',
#  'source': 'New York Times',
#  'subsection': '',
#  'title': 'Billionaire No More: Patagonia Founder Gives Away the Company',
#  'type': 'Article',
#  'updated': '2022-09-21 18:05:13',
#  'uri': 'nyt://article/6b915b80-14bb-5063-b0ec-2505eb55fc0d',
#  'url': 'https://www.nytimes.com/2022/09/14/climate/patagonia-climate-philanthropy-chouinard.html'}

# %%
# Covid US cumulative data
df_us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv')
df_states = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')
df_counties = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

df_us
# Out:
#            date     cases   deaths
# 0    2020-01-21         1        0
# 1    2020-01-22         1        0
# 2    2020-01-23         1        0
# 3    2020-01-24         2        0
# 4    2020-01-25         3        0
# ..          ...       ...      ...
# 992  2022-10-09  96447636  1058245
# 993  2022-10-10  96471883  1058408
# 994  2022-10-11  96522454  1059005
# 995  2022-10-12  96596469  1059792
# 996  2022-10-13  96671641  1060430
#
# [997 rows x 3 columns]

# %%
df_states
# Out:
#              date          state  fips    cases  deaths
# 0      2020-01-21     Washington    53        1       0
# 1      2020-01-22     Washington    53        1       0
# 2      2020-01-23     Washington    53        1       0
# 3      2020-01-24       Illinois    17        1       0
# 4      2020-01-24     Washington    53        1       0
# ...           ...            ...   ...      ...     ...
# 52921  2022-10-13       Virginia    51  2101702   22012
# 52922  2022-10-13     Washington    53  1826131   14468
# 52923  2022-10-13  West Virginia    54   603859    7457
# 52924  2022-10-13      Wisconsin    55  1879656   15344
# 52925  2022-10-13        Wyoming    56   177635    1904
#
# [52926 rows x 5 columns]

# %%
df_counties
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 2502827  2022-05-13  Sweetwater     Wyoming  56037.0  11088   126.0
# 2502828  2022-05-13       Teton     Wyoming  56039.0  10074    16.0
# 2502829  2022-05-13       Uinta     Wyoming  56041.0   5643    39.0
# 2502830  2022-05-13    Washakie     Wyoming  56043.0   2358    44.0
# 2502831  2022-05-13      Weston     Wyoming  56045.0   1588    18.0
#
# [2502832 rows x 6 columns]

# %%
# Covid US live data
df_us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us.csv')
df_states = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-states.csv')
df_counties = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

df_us
# Out:
#          date     cases   deaths
# 0  2022-10-14  96671641  1060430
