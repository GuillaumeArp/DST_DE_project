# %% [markdown]
# # Imports

# %%
import requests
import pandas as pd
from pprint import pprint
import json
from dotenv import load_dotenv
import os
import time
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

load_dotenv()
KEY=os.getenv("APIKEY")
USERNAME=os.getenv("USERNAME")
USERPWD=os.getenv("USERPWD")

# %% [markdown]
# # Articles Search

# %%
def get_articles(filename, year='full', clean=True):
    """Requests articles about Covid-19 from the New York Times API, returns a list of dictionaries, and saves it to a json file.

    Args:
        filename (_type_): Name of the json file to save the articles to.
        year (str, optional): Year range of the articles search, can be either 2020, 2021 or 2022. Any other value gets the full data starting from Jan 2020. Defaults to 'full'.
        clean (bool, optional): Toggles the cleaning of unwanted keys. Defaults to True.

    Returns:
        _type_: a list object containing dictionaries of articles data.
    """
    
    begin_date_list_2020 = ['20200101', '20200201', '20200301', '20200401', '20200501', '20200601', '20200701', '20200801', '20200901', '20201001', '20201101', '20201201']
    begin_date_list_2021 = ['20210101', '20210201', '20210301', '20210401', '20210501', '20210601', '20210701', '20210801', '20210901', '20211001', '20211101', '20211201']
    begin_date_list_2022 = ['20220101', '20220201', '20220301', '20220401', '20220501', '20220601', '20220701', '20220801', '20220901', '20221001', '20221101', '20221201']    
    begin_date_list = begin_date_list_2020 + begin_date_list_2021 + begin_date_list_2022

    end_date_list_2020 = ['20200131', '20200229', '20200331', '20200430', '20200531', '20200630', '20200731', '20200831', '20200930', '20201031', '20201130', '20201231']
    end_date_list_2021 = ['20210131', '20210228', '20210331', '20210430', '20210531', '20210630', '20210731', '20210831', '20210930', '20211031', '20211130', '20211231']
    end_date_list_2022 = ['20220131', '20220228', '20220331', '20220430', '20220531', '20220630', '20220731', '20220831', '20220930', '20221031', '20221130', '20221231']    
    end_date_list = end_date_list_2020 + end_date_list_2021 + end_date_list_2022
    
    if year == 2020:
        begin_date = begin_date_list_2020
        end_date = end_date_list_2020
    elif year == 2021:
        begin_date = begin_date_list_2021
        end_date = end_date_list_2021
    elif year == 2022:
        begin_date = begin_date_list_2022
        end_date = end_date_list_2022
    else:
        begin_date = begin_date_list
        end_date = end_date_list
    
    results_list = []    
    requestHeaders = {"Accept": "application/json"}
    
    for i in range(len(begin_date)):
        for j in range(101):
            url = f"https://api.nytimes.com/svc/search/v2/articlesearch.json?begin_date={begin_date[i]}&end_date={end_date[i]}&fq=headline%3A(%22covid%22%20%22coronavirus%22)&page={j}&sort=oldest&api-key={KEY}"
            
            try:
                response = requests.get(url, headers=requestHeaders).json()
                response_list = response['response']['docs']
                
                for k in response_list:
                    results_list.append(k)                        
                
                time.sleep(6.1)
                
            except:
                break
            
    if clean:
        lst_clean = results_list.copy()
        for i in lst_clean:
            i.pop('multimedia', None)

        with open(filename, 'w') as outfile:
            json.dump(lst_clean, outfile, indent=4)

        return lst_clean
    
    else:       
        with open(filename, 'w') as outfile:
            json.dump(results_list, outfile, indent=4)
        
        return results_list

# %%
def clean_articles(lst):
    """Removes unwanted keys from a list of dictionaries.

    Args:
        lst (_type_): The input list of dictionaries to clean.

    Returns:
        _type_: A list of dictionaries with the unwanted keys removed.
    """

    lst_clean = lst.copy()
    for i in lst_clean:
        i.pop('multimedia', None)
        
    return lst_clean

# %%
# articles_2020 = get_articles('src/articles_2020.json', 2020, False)
# len(articles_2020)
# Out:
# 4606

# %%
# articles_2021 = get_articles('src/articles_2021.json', 2021, False)
# len(articles_2021)
# Out:
# 1408

# %%
# articles_2022 = get_articles('src/articles_2022.json', 2022, False)
# len(articles_2022)
# Out:
# 983

# %%
# articles_full = articles_2020 + articles_2021 + articles_2022

# with open('src/articles_full_raw.json', "w") as outfile:
#     json.dump(articles_full, outfile, indent=4)

# %%
with open('src/articles_full_raw.json', "r") as infile:
    articles_full = json.load(infile)

# %%
articles_full_clean = clean_articles(articles_full)

with open('src/articles_full_clean.json', "w") as outfile:
    json.dump(articles_full_clean, outfile, indent=4)

# %%
articles_full_clean[-5:]
# Out:
# [{'abstract': 'And the F.D.A. cleared updated boosters for children.',
#   'web_url': 'https://www.nytimes.com/2022/10/12/briefing/chinas-covid-politics.html',
#   'snippet': 'And the F.D.A. cleared updated boosters for children.',
#   'lead_paragraph': 'Welcome to the Virus Briefing, your comprehensive guide to the latest news and expert analysis on the coronavirus pandemic and other outbreaks.',
#   'source': 'The New York Times',
#   'headline': {'main': 'China’s Covid politics',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'}],
#   'pub_date': '2022-10-12T20:23:38+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Jonathan Wolfe',
#    'person': [{'firstname': 'Jonathan',
#      'middlename': None,
#      'lastname': 'Wolfe',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/22a96ddb-fa5a-5547-8a6b-43de7a208fff',
#   'word_count': 1858,
#   'uri': 'nyt://article/22a96ddb-fa5a-5547-8a6b-43de7a208fff'},
#  {'abstract': 'Plus President Biden’s security strategy and Myanmar cracks down on journalists.',
#   'web_url': 'https://www.nytimes.com/2022/10/12/briefing/china-covid-test-biden-russia-myanmar.html',
#   'snippet': 'Plus President Biden’s security strategy and Myanmar cracks down on journalists.',
#   'lead_paragraph': 'Testing every citizen for the coronavirus several times a week became central to China’s “zero-Covid” strategy earlier this year, when a stubborn strain of the coronavirus rippled through the country.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Your Thursday Briefing: China’s Covid Testing Problems',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'War and Armed Conflicts',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'News and News Media',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Freedom of the Press',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Korean Food (Cuisine)',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Russian Invasion of Ukraine (2022)',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Biden, Joseph R Jr', 'rank': 7, 'major': 'N'},
#    {'name': 'persons',
#     'value': 'Jones, Alex (1974- )',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Lansbury, Angela', 'rank': 9, 'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 10, 'major': 'N'},
#    {'name': 'glocations', 'value': 'Myanmar', 'rank': 11, 'major': 'N'},
#    {'name': 'glocations', 'value': 'South Korea', 'rank': 12, 'major': 'N'}],
#   'pub_date': '2022-10-12T20:42:47+0000',
#   'document_type': 'article',
#   'news_desk': 'NYTNow',
#   'section_name': 'Briefing',
#   'byline': {'original': 'By Daniel E. Slotnik',
#    'person': [{'firstname': 'Daniel',
#      'middlename': 'E.',
#      'lastname': 'Slotnik',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'briefing',
#   '_id': 'nyt://article/122af249-8382-5260-8ddf-30aaedfab9da',
#   'word_count': 1307,
#   'uri': 'nyt://article/122af249-8382-5260-8ddf-30aaedfab9da'},
#  {'abstract': 'The findings strengthened calls from scientists for more expansive care options for long Covid patients.',
#   'web_url': 'https://www.nytimes.com/2022/10/12/health/long-covid.html',
#   'snippet': 'The findings strengthened calls from scientists for more expansive care options for long Covid patients.',
#   'lead_paragraph': 'A study of tens of thousands of people in Scotland found that one in 20 people who had been sick with Covid reported not recovering at all, and another four in 10 said they had not fully recovered from their infections many months later.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Nearly Half of Covid Patients Haven’t Fully Recovered Months Later, Study Finds',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Long Covid',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Chronic Condition (Health)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Research', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Disease Rates', 'rank': 5, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'your-feed-healthcare',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Nature Communications (Journal)',
#     'rank': 7,
#     'major': 'N'}],
#   'pub_date': '2022-10-12T22:30:21+0000',
#   'document_type': 'article',
#   'news_desk': 'Science',
#   'section_name': 'Health',
#   'byline': {'original': 'By Benjamin Mueller',
#    'person': [{'firstname': 'Benjamin',
#      'middlename': None,
#      'lastname': 'Mueller',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/e3d62742-380d-5f09-a2dc-bf280dd4201f',
#   'word_count': 975,
#   'uri': 'nyt://article/e3d62742-380d-5f09-a2dc-bf280dd4201f'},
#  {'abstract': 'As our third pandemic winter approaches, you can mitigate risk without missing out.',
#   'web_url': 'https://www.nytimes.com/2022/10/15/well/covid-holiday-plans.html',
#   'snippet': 'As our third pandemic winter approaches, you can mitigate risk without missing out.',
#   'lead_paragraph': 'At this stage in the long slog of the pandemic, many of us are forgoing masks in places we previously wore them and getting together indoors when we had formerly avoided it. But the holidays throw new variables at everyone’s risk calculus. People trek across the country to see each other. Families crowd around dinner tables, with older, more vulnerable people sitting beside their younger relatives.',
#   'source': 'The New York Times',
#   'headline': {'main': 'Another Covid Wave Could Be Coming. Here’s How to Make Your Holiday Plans.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Content Type: Service',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Holidays and Special Occasions',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coronavirus Risks and Safety Concerns',
#     'rank': 4,
#     'major': 'N'}],
#   'pub_date': '2022-10-15T09:00:14+0000',
#   'document_type': 'article',
#   'news_desk': 'Well',
#   'section_name': 'Well',
#   'byline': {'original': 'By Dani Blum',
#    'person': [{'firstname': 'Dani',
#      'middlename': None,
#      'lastname': 'Blum',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/459b482f-3394-594c-b694-19e9ccccf8a2',
#   'word_count': 1562,
#   'uri': 'nyt://article/459b482f-3394-594c-b694-19e9ccccf8a2'},
#  {'abstract': 'Xi Jinping doubled down on the idea that the measures have saved lives and vowed to continue the stringent set of policies.',
#   'web_url': 'https://www.nytimes.com/2022/10/16/world/asia/china-is-sticking-to-its-zero-covid-policy.html',
#   'snippet': 'Xi Jinping doubled down on the idea that the measures have saved lives and vowed to continue the stringent set of policies.',
#   'lead_paragraph': 'China’s leader, Xi Jinping, on Sunday dashed any hopes that the “zero Covid” policy — which attempts to eliminate coronavirus infections with costly lockdowns — would end in the coming months.',
#   'source': 'The New York Times',
#   'headline': {'main': 'China is sticking to its ‘zero Covid’ policy.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': None,
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Coronavirus (2019-nCoV)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'glocations', 'value': 'China', 'rank': 2, 'major': 'N'},
#    {'name': 'persons', 'value': 'Xi Jinping', 'rank': 3, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Medicine and Health',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Science and Technology',
#     'rank': 5,
#     'major': 'N'}],
#   'pub_date': '2022-10-16T08:30:25+0000',
#   'document_type': 'article',
#   'news_desk': 'Foreign',
#   'section_name': 'World',
#   'subsection_name': 'Asia Pacific',
#   'byline': {'original': 'By Alexandra Stevenson',
#    'person': [{'firstname': 'Alexandra',
#      'middlename': None,
#      'lastname': 'Stevenson',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/6707bf72-552b-5d75-a28d-93ba25a943fa',
#   'word_count': 515,
#   'uri': 'nyt://article/6707bf72-552b-5d75-a28d-93ba25a943fa'}]

# %% [markdown]
# # MongoDB

# %%
client = MongoClient(f"mongodb+srv://{USERNAME}:{USERPWD}@nyt-de.ganwi.mongodb.net/?retryWrites=true&w=majority", server_api=ServerApi('1'), serverSelectionTimeoutMS=5000)
db = client.test

try:
    pprint(client.server_info())
except Exception:
    pprint("Unable to connect to the server.")
    
col = db.create_collection('articles')
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1666354403, 14),
#                   'signature': {'hash': b'\xc7\xb2L\x95\xaa\xd18\xb8'
#                                         b'\xf2\xeb\xf5\xf8>\xdd\x1d\x7f'
#                                         b'\x7f\x1a\x8cH',
#                                 'keyId': 7156162285394722821}},
#  'allocator': 'tcmalloc',
#  'bits': 64,
#  'debug': False,
#  'gitVersion': '0ca11aca38c75d3c8fb5bac5bd103b950718a896',
#  'javascriptEngine': 'mozjs',
#  'maxBsonObjectSize': 16777216,
#  'modules': ['enterprise'],
#  'ok': 1.0,
#  'operationTime': Timestamp(1666354403, 14),
#  'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'],
#  'sysInfo': 'deprecated',
#  'version': '6.1.0',
#  'versionArray': [6, 1, 0, 0]}

# %%
article_test = articles_full_clean[:5]

results = col.insert_many(article_test)
results.inserted_ids
# Out:
# ['nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#  'nyt://article/deeaba82-0dcb-5fa0-9f69-e6c1dd3aa2c4',
#  'nyt://article/d6e895ce-f684-5e05-b5d6-ed00d833c684',
#  'nyt://article/4f2c6360-3926-5e87-bd74-6fa8916e5d08',
#  'nyt://article/6468ef74-43a0-5640-9d89-2e838129da4d']

# %%
pprint(list(col.find()))
# Out:
# [{'_id': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#   'abstract': 'The two new patients will add to fears that the virus will '
#               'spread further outside China’s borders.',
#   'byline': {'organization': None,
#              'original': 'By Sui-Lee Wee',
#              'person': [{'firstname': 'Sui-lee',
#                          'lastname': 'Wee',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Japan and Thailand Confirm New Cases of Chinese '
#                        'Coronavirus',
#                'name': None,
#                'print_headline': 'Japan Confirms Case of New Coronavirus; '
#                                  'Patient Had Visited China',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Viruses'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Epidemics'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 3,
#                 'value': 'China'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 4,
#                 'value': 'Japan'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 5,
#                 'value': 'Thailand'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 6,
#                 'value': 'Coronavirus (2019-nCoV)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'Pneumonia'}],
#   'lead_paragraph': 'BEIJING — Thailand and Japan each reported new cases of a '
#                     'coronavirus that has left two people dead and at least 40 '
#                     'sick in China, adding to concerns about the spread of the '
#                     'virus beyond Chinese borders ahead of a major holiday. ',
#   'news_desk': 'Foreign',
#   'print_page': '8',
#   'print_section': 'A',
#   'pub_date': '2020-01-16T03:29:27+0000',
#   'section_name': 'World',
#   'snippet': 'The two new patients will add to fears that the virus will '
#              'spread further outside China’s borders.',
#   'source': 'The New York Times',
#   'subsection_name': 'Asia Pacific',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/8e3a5bd7-7252-5c90-abdd-c912643895c3',
#   'web_url': 'https://www.nytimes.com/2020/01/15/world/asia/coronavirus-japan-china.html',
#   'word_count': 1172},
#  {'_id': 'nyt://article/deeaba82-0dcb-5fa0-9f69-e6c1dd3aa2c4',
#   'abstract': 'Passengers from Wuhan, China, will be screened at J.F.K. '
#               'beginning Friday night, and in San Francisco and Los Angeles '
#               'starting on Saturday.',
#   'byline': {'organization': None,
#              'original': 'By Denise Grady',
#              'person': [{'firstname': 'Denise',
#                          'lastname': 'Grady',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Three U.S. Airports to Check Passengers for a Deadly '
#                        'Chinese Coronavirus',
#                'name': None,
#                'print_headline': 'U.S. Airports Will Screen China Flights For '
#                                  'Infection',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Coronavirus (2019-nCoV)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 2,
#                 'value': 'Wuhan (China)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Airport Security'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 4,
#                 'value': 'Kennedy International Airport (Queens, NY)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 5,
#                 'value': 'Los Angeles International Airport'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'San Francisco International Airport'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 7,
#                 'value': 'Centers for Disease Control and Prevention'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 8,
#                 'value': 'Los Angeles (Calif)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 9,
#                 'value': 'San Francisco (Calif)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 10,
#                 'value': 'New York City'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 11,
#                 'value': 'Viruses'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 12,
#                 'value': 'Epidemics'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 13,
#                 'value': 'Respiratory Diseases'}],
#   'lead_paragraph': 'Airports in New York, San Francisco and Los Angeles will '
#                     'begin screening passengers arriving from Wuhan, China, '
#                     'for infection with a mysterious respiratory virus that '
#                     'has killed two people and sickened at least 45 overseas, '
#                     'the Centers for Disease Control and Prevention announced '
#                     'on Friday.',
#   'news_desk': 'Science',
#   'print_page': '10',
#   'print_section': 'A',
#   'pub_date': '2020-01-17T19:00:08+0000',
#   'section_name': 'Health',
#   'snippet': 'Passengers from Wuhan, China, will be screened at J.F.K. '
#              'beginning Friday night, and in San Francisco and Los Angeles '
#              'starting on Saturday.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/deeaba82-0dcb-5fa0-9f69-e6c1dd3aa2c4',
#   'web_url': 'https://www.nytimes.com/2020/01/17/health/china-coronavirus-airport-screening.html',
#   'word_count': 841},
#  {'_id': 'nyt://article/d6e895ce-f684-5e05-b5d6-ed00d833c684',
#   'abstract': 'A top Chinese government-appointed expert says a mysterious '
#               'respiratory illness that has killed at least four people can be '
#               'transmitted by humans, heightening concern about the outbreak.',
#   'byline': {'organization': None,
#              'original': 'By Javier C. Hernández and Austin Ramzy',
#              'person': [{'firstname': 'Javier',
#                          'lastname': 'Hernández',
#                          'middlename': 'C.',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Austin',
#                          'lastname': 'Ramzy',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'China Confirms New Coronavirus Spreads From Humans to '
#                        'Humans',
#                'name': None,
#                'print_headline': 'China Says New Virus Can Be Spread by Humans',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Coronavirus (2019-nCoV)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Respiratory Diseases'},
#                {'major': 'N', 'name': 'subject', 'rank': 3, 'value': 'Viruses'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 4,
#                 'value': 'World Health Organization'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 5,
#                 'value': 'China'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 6,
#                 'value': 'Beijing (China)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 7,
#                 'value': 'Seoul (South Korea)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 8,
#                 'value': 'Bangkok (Thailand)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 9,
#                 'value': 'Japan'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 10,
#                 'value': 'Wuhan (China)'}],
#   'lead_paragraph': 'WUHAN, China — The mysterious coronavirus that has killed '
#                     'at least four people and sickened more than 200 in China '
#                     'is capable of spreading from person to person, a '
#                     'prominent Chinese scientist said on Monday, adding to '
#                     'fears of a broader epidemic.',
#   'news_desk': 'Foreign',
#   'print_page': '10',
#   'print_section': 'A',
#   'pub_date': '2020-01-20T10:59:15+0000',
#   'section_name': 'World',
#   'snippet': 'A top Chinese government-appointed expert says a mysterious '
#              'respiratory illness that has killed at least four people can be '
#              'transmitted by humans, heightening concern about the outbreak.',
#   'source': 'The New York Times',
#   'subsection_name': 'Asia Pacific',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/d6e895ce-f684-5e05-b5d6-ed00d833c684',
#   'web_url': 'https://www.nytimes.com/2020/01/20/world/asia/coronavirus-china-symptoms.html',
#   'word_count': 1320},
#  {'_id': 'nyt://article/4f2c6360-3926-5e87-bd74-6fa8916e5d08',
#   'abstract': 'The new virus has killed at least nine and infected more than '
#               '400 people in China, with confirmed cases in the United States, '
#               'Taiwan, Thailand, Japan and South Korea.',
#   'byline': {'organization': None,
#              'original': 'By Javier C. Hernández',
#              'person': [{'firstname': 'Javier',
#                          'lastname': 'Hernández',
#                          'middlename': 'C.',
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'The Test a Deadly Coronavirus Outbreak Poses to '
#                        'China’s Leadership',
#                'name': None,
#                'print_headline': 'As Infections Mount, Virus Poses Test for '
#                                  'China',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Coronavirus (2019-nCoV)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 2,
#                 'value': 'Wuhan (China)'},
#                {'major': 'N',
#                 'name': 'glocations',
#                 'rank': 3,
#                 'value': 'China'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Politics and Government'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 5,
#                 'value': 'Epidemics'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 6,
#                 'value': 'World Health Organization'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 7,
#                 'value': 'SARS (Severe Acute Respiratory Syndrome)'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 8,
#                 'value': 'Respiratory Diseases'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 9,
#                 'value': 'Airport Security'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 10,
#                 'value': 'Airports'}],
#   'lead_paragraph': 'WUHAN, China — Facing growing pressure to contain a '
#                     'deadly viral outbreak that has spread halfway around the '
#                     'world, China’s ruling Communist Party raced on Tuesday to '
#                     'confront the disease, slapping restrictions on the city '
#                     'where it started and warning that anyone who hides '
#                     'infections will be “forever nailed to history’s pillar of '
#                     'shame.”',
#   'news_desk': 'Foreign',
#   'print_page': '1',
#   'print_section': 'A',
#   'pub_date': '2020-01-21T08:26:13+0000',
#   'section_name': 'World',
#   'snippet': 'The new virus has killed at least nine and infected more than '
#              '400 people in China, with confirmed cases in the United States, '
#              'Taiwan, Thailand, Japan and South Korea.',
#   'source': 'The New York Times',
#   'subsection_name': 'Asia Pacific',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/4f2c6360-3926-5e87-bd74-6fa8916e5d08',
#   'web_url': 'https://www.nytimes.com/2020/01/21/world/asia/china-coronavirus-wuhan.html',
#   'word_count': 1471},
#  {'_id': 'nyt://article/6468ef74-43a0-5640-9d89-2e838129da4d',
#   'abstract': "Here's what you need to know.",
#   'byline': {'organization': None,
#              'original': 'By Chris Stanford',
#              'person': [{'firstname': 'Chris',
#                          'lastname': 'Stanford',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': 'Impeachment Trial, Davos, Coronavirus: Your Tuesday '
#                        'Briefing',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [],
#   'lead_paragraph': '(Want to get this briefing by email? Here’s the sign-up.)',
#   'news_desk': 'NYTNow',
#   'pub_date': '2020-01-21T10:22:53+0000',
#   'section_name': 'Briefing',
#   'snippet': "Here's what you need to know.",
#   'source': 'The New York Times',
#   'type_of_material': 'briefing',
#   'uri': 'nyt://article/6468ef74-43a0-5640-9d89-2e838129da4d',
#   'web_url': 'https://www.nytimes.com/2020/01/21/briefing/impeachment-trial-davos-coronavirus.html',
#   'word_count': 1208}]

# %%
db_nyt = client.nyt

pprint(db.list_collection_names())

col_nyt = db_nyt['articles']
# Out:
# ['articles']

# %%
len(articles_full_clean)
# Out:
# 6997

# %%
results = col_nyt.insert_many(articles_full_clean)

# %% [markdown]
# # Covid Cases Data

# %%
# Covid US cumulative data
df_us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv')
df_states = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv')
df_counties = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv')

df_us
# Out:
#            date     cases   deaths
# 0    2020-01-21         1        0
# 1    2020-01-22         1        0
# 2    2020-01-23         1        0
# 3    2020-01-24         2        0
# 4    2020-01-25         3        0
# ..          ...       ...      ...
# 992  2022-10-09  96447636  1058245
# 993  2022-10-10  96471883  1058408
# 994  2022-10-11  96522454  1059005
# 995  2022-10-12  96596469  1059792
# 996  2022-10-13  96671641  1060430
#
# [997 rows x 3 columns]

# %%
df_states
# Out:
#              date          state  fips    cases  deaths
# 0      2020-01-21     Washington    53        1       0
# 1      2020-01-22     Washington    53        1       0
# 2      2020-01-23     Washington    53        1       0
# 3      2020-01-24       Illinois    17        1       0
# 4      2020-01-24     Washington    53        1       0
# ...           ...            ...   ...      ...     ...
# 52921  2022-10-13       Virginia    51  2101702   22012
# 52922  2022-10-13     Washington    53  1826131   14468
# 52923  2022-10-13  West Virginia    54   603859    7457
# 52924  2022-10-13      Wisconsin    55  1879656   15344
# 52925  2022-10-13        Wyoming    56   177635    1904
#
# [52926 rows x 5 columns]

# %%
df_counties
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 2502827  2022-05-13  Sweetwater     Wyoming  56037.0  11088   126.0
# 2502828  2022-05-13       Teton     Wyoming  56039.0  10074    16.0
# 2502829  2022-05-13       Uinta     Wyoming  56041.0   5643    39.0
# 2502830  2022-05-13    Washakie     Wyoming  56043.0   2358    44.0
# 2502831  2022-05-13      Weston     Wyoming  56045.0   1588    18.0
#
# [2502832 rows x 6 columns]

# %%
# Covid US live data
df_us = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us.csv')
df_states = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-states.csv')
df_counties = pd.read_csv('https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-counties.csv')

df_us
# Out:
#          date     cases   deaths
# 0  2022-10-14  96671641  1060430
